# %%
import pandas as pd

#Carrega o arquivo csv original
df = pd.read_csv('radar_projetos.csv', sep = ';', encoding='utf-8-sig')

#Identifica as variaveis do ementa nulo e as substitui
df['ementa'] = df['ementa'].fillna('Ementa não informada')

#Cria um novo arquivo csv limpo
df.to_csv('lista_projetos_tratada.csv', sep = ';', encoding='utf-8-sig')
